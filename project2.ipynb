# %%
import pandas as pd
import csv
import re

# %%
infile = open("/Users/malcolmbarnes/Desktop/is360_project2/tournamentinfo.txt")

# %%
infile.readlines()
# Out:
# ['-----------------------------------------------------------------------------------------\r\n',
#  ' Pair | Player Name                     |Total|Round|Round|Round|Round|Round|Round|Round| \r\n',
#  ' Num  | USCF ID / Rtg (Pre->Post)       | Pts |  1  |  2  |  3  |  4  |  5  |  6  |  7  | \r\n',
#  '-----------------------------------------------------------------------------------------\r\n',
#  '    1 | GARY HUA                        |6.0  |W  39|W  21|W  18|W  14|W   7|D  12|D   4|\r\n',
#  '   ON | 15445895 / R: 1794   ->1817     |N:2  |W    |B    |W    |B    |W    |B    |W    |\r\n',
#  '-----------------------------------------------------------------------------------------\r\n',
#  '    2 | DAKSHESH DARURI                 |6.0  |W  63|W  58|L   4|W  17|W  16|W  20|W   7|\r\n',
#  '   MI | 14598900 / R: 1553   ->1663     |N:2  |B    |W    |B    |W    |B    |W    |B    |\r\n',
# ...

# %%
for line in infile:
    line = line.rstrip()
    clean= re.findall(['A-Z'], line)
    if len(clean) > 0:
        print clean

# %% [markdown]
# I was trying to extract the information that I want from the text file using regex. There is no output here but I don't get an error either. Then, I would take this output as a series and convert the series to a dataframe. Then I would write the dataframe to a csv file.
# series.to_frame(name)
# df.to_csv(outFile)

# %%
df= pd.dataframe(clean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-81dcec83b261> in <module>()
# ----> 1 df= pd.dataframe(clean)
#
# AttributeError: 'module' object has no attribute 'dataframe'

# %%
outfile= pd.DataFrame.to_csv("cleantournament.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5aa4fd8c019f> in <module>()
# ----> 1 outfile= pd.DataFrame.to_csv("cleantournament.txt")
#
# TypeError: unbound method to_csv() must be called with DataFrame instance as first argument (got str instance instead)

# %% [markdown]
# It keeps saying that I cannot import dataframes when I tried to load it at step 1.
